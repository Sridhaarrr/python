# %%
#from googlesearch import search
from newspaper import Article, Config
import nltk
import docx
import os
from datetime import datetime,date
import re
from csv import reader
import pandas as pd
import time

directory_name = 'Negative_String_Search_' + date.today().strftime("%m-%d-%Y")
if(not os.path.exists(directory_name)):
    directory_name = 'Negative_String_Search_' + date.today().strftime("%m-%d-%Y")
    os.makedirs(directory_name)

df=pd.read_excel('Malegam_past7_2023-03-16.xlsx')
user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'
config = Config()
config.browser_user_agent = user_agent

df['STATUS']='NOT RUN'

for idx,url in enumerate(df['Redirect']):
    print(idx,url)
    
    article = Article(url)

    try:
        print("Inside Try")
        article.download()
        article.parse()
        #article.nlp()
        doc=docx.Document()
        doc.add_paragraph('Company:')
        doc.add_paragraph(df['Company'][idx])
        doc.add_paragraph('Article URL:')
        doc.add_paragraph(url)
        #doc.add_paragraph('Article Summary:')
        #doc.add_paragraph(article.summary)
        doc.add_paragraph('Article Title:')
        doc.add_paragraph(article.title)
        doc.add_paragraph('Full Article:')
        doc.add_paragraph(article.text)
        article_text=article.text
        filename=df['Company'][idx]
        Value=df['Value'][idx]
        filename = filename+Value+'Crores.docx'
        path = os.path.join(directory_name,filename)
        doc.save(path)
        df['STATUS'].iloc[idx]='SUCCESS'
        time.sleep(60)
    except:
        df['STATUS'].iloc[idx]='FAILURE'
        continue

df['STATUS']
# Out:
# D:\lib\site-packages\openpyxl\styles\stylesheet.py:214: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 0 https://www.firstpost.com/business/india-uae-bilateral-trade-to-cross-usd-88-billion-this-year-up-from-usd-73-billion-last-fiscal-11677371.html
# Inside Try
# D:\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# 1 https://finance.yahoo.com/news/surface-vision-inspection-global-market-124400133.html
# Inside Try
# 2 https://finance.yahoo.com/news/global-sustained-release-excipients-market-151400816.html
# Inside Try
# 3 https://finance.yahoo.com/news/physical-security-market-size-hit-183100868.html
# ...

# %%
pip install --trusted-host=pypi.org --trusted-host=files.pythonhosted.org --user newspaper

# %%
from newspaper import Article, Config
import nltk
import docx
import os
from datetime import datetime,date
import re
from csv import reader
import pandas as pd
import time

directory_name = 'Negative_String_Search_' + date.today().strftime("%m-%d-%Y")
if(not os.path.exists(directory_name)):
    directory_name = 'Negative_String_Search_' + date.today().strftime("%m-%d-%Y")
    os.makedirs(directory_name)

df=pd.read_excel('Malegam_past7_2022-08-01.xlsx')
user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'
config = Config()
config.browser_user_agent = user_agent

df['STATUS']='NOT RUN'
article = Article('https://www.firstpost.com/business/india-uae-bilateral-trade-to-cross-usd-88-billion-this-year-up-from-usd-73-billion-last-fiscal-11677371.html',config=config)
article.download()
article.parse()
#article.nlp()
doc=docx.Document()
doc.add_paragraph('Company:')
#doc.add_paragraph(df['Company'][idx])
doc.add_paragraph('Article URL:')
#doc.add_paragraph(url)
#doc.add_paragraph('Article Summary:')
#doc.add_paragraph(article.summary)
doc.add_paragraph('Article Title:')
doc.add_paragraph(article.title)
doc.add_paragraph('Full Article:')
doc.add_paragraph(article.text)
article_text=article.text
article_text
# Out:
# ---------------------------------------------------------------------------
# ArticleException                          Traceback (most recent call last)
# <ipython-input-15-c36fa5642baa> in <module>
#      22 article = Article('https://www.firstpost.com/business/india-uae-bilateral-trade-to-cross-usd-88-billion-this-year-up-from-usd-73-billion-last-fiscal-11677371.html',config=config)
#      23 article.download()
# ---> 24 article.parse()
#      25 #article.nlp()
#      26 doc=docx.Document()
#
# D:\lib\site-packages\newspaper\article.py in parse(self)
#     189
#     190     def parse(self):
# --> 191         self.throw_if_not_downloaded_verbose()
#     192
#     193         self.doc = self.config.get_parser().fromstring(self.html)
#
# D:\lib\site-packages\newspaper\article.py in throw_if_not_downloaded_verbose(self)
#     529             raise ArticleException('You must `download()` an article first!')
# ...

# %%
pip install --trusted-host=pypi.org --trusted-host=files.pythonhosted.org --user newspaper3k

# %%
from pdf2docx import Converter
import os

# # # dir_path for input reading and output files & a for loop # # #

path_input = 'C:/Users/018598/Circulars/'
path_output = 'C:/Users/018598/Negative_String_Search_03-15-2022/'

for file in os.listdir(path_input):
    cv = Converter(path_input+file)
    cv.convert(path_output+file+'.docx', start=0, end=None)
    cv.close()
    print(file)

# %%
from theano import *
import numpy

x = tensor.fvector('x')
target = tensor.fscalar('target')

W = theano.shared(numpy.asarray([0.1, 0.25, 0.15, 0.3]), 'W')
print ("Weights: ", W.get_value())

y = (x * W).sum()
cost = tensor.sqr(target - y)
gradients = tensor.grad(cost, [W])
W_updated = W - (0.1 * gradients[0])
updates = [(W, W_updated)]

# %%
f = function([x, target], y, updates=updates)
for i in range(10):
   output = f([1.0, 1.0, 1.0, 1.0], 100.0)
   print ("iteration: ", i)
   print ("Modified Weights: ", W.get_value())
   print ("Output: ", output)
