# %%
import pandas as pd
data = pd.read_excel('file.xlsx', sheet_name=1)
data.head()
data = data.dropna()
data
# Out:
#     V_CUST_CODE         V_ACCT_NO D_OPEN_DATE  V_PROD_CODE      V_PROD_DESC  \
# 0       9463999  1709155000003774    06-12-12          155    SB - RESIDENT
# 1      10448555  1698172000001624    03-10-13          172  FREEDOM SAVINGS
# 3        250651  1197155000009031    04-09-92          155    SB - RESIDENT
# 4      15771490  1351155000007367    08-03-18          155    SB - RESIDENT
# 5       7495557  1641155000013931    11-11-11          155    SB - RESIDENT
# ..          ...               ...         ...          ...              ...
# 73      9182599  1138155000084063    01-03-13          155    SB - RESIDENT
# 74     16032572  1830155000014097    30-01-18          155    SB - RESIDENT
# 75     11336377  1642155000032303    23-09-14          155    SB - RESIDENT
# 76      9550433  1689155000020433    11-05-13          155    SB - RESIDENT
# 77      8325616  1650155000059911    27-04-18          155    SB - RESIDENT
#
# ...

# %%
import numpy as np
def softmax(x):
    """Compute softmax values for each sets of scores in x."""
    e_x = np.exp(x - np.max(x))
    return e_x / e_x.sum()

# %%
z = data["CTCR"]
(z-np.median(z))/(np.percentile(z, 75)-np.percentile(z, 25))

# %%
d = data[["AVGBAL", "TOTDR", "TOTCR", "CTDR", "CTCR"]]
for i in d.columns:
    z = d[i]
    yy = (z-np.median(z))/(np.percentile(z, 75)-np.percentile(z, 25))
    g = softmax(yy)
    d['c'+i] = g
# Out:
# D:\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
di = data[["V_CUST_CODE","V_ACCT_NO", "V_PROD_DESC"]]

# %%
features.groupby('V_PROD_DESC').count()
# Out:
#                               V_CUST_CODE  AVGBAL  TOTDR  TOTCR  CTDR  CTCR  \
# V_PROD_DESC
# FREEDOM SAVINGS                         3       3      3      3     3     3
# KVB JAN DHAN YOJANA (KVBJDY)            1       1      1      1     1     1
# SB - KVB SAKTHI                         1       1      1      1     1     1
# SB - RAINBOW SB                         5       5      5      5     5     5
# SB - RESIDENT                          48      48     48     48    48    48
# SMART SB RESIDENT                       4       4      4      4     4     4
# YUVASHAKTI                              2       2      2      2     2     2
#
#                               cAVGBAL  cTOTDR  cTOTCR  cCTDR  cCTCR
# V_PROD_DESC
# FREEDOM SAVINGS                     3       3       3      3      3
# KVB JAN DHAN YOJANA (KVBJDY)        1       1       1      1      1
# SB - KVB SAKTHI                     1       1       1      1      1
# ...

# %%
features = pd.concat([di,d], axis = 1)
features
# Out:
#     V_CUST_CODE         V_ACCT_NO      V_PROD_DESC     AVGBAL      TOTDR  \
# 0       9463999  1709155000003774    SB - RESIDENT    3409.03   54220.72
# 1      10448555  1698172000001624  FREEDOM SAVINGS    6864.75   64520.24
# 3        250651  1197155000009031    SB - RESIDENT   12867.00    3108.85
# 4      15771490  1351155000007367    SB - RESIDENT  183863.19  340489.70
# 5       7495557  1641155000013931    SB - RESIDENT    1144.11    2917.72
# ..          ...               ...              ...        ...        ...
# 73      9182599  1138155000084063    SB - RESIDENT    4469.95    1667.85
# 74     16032572  1830155000014097    SB - RESIDENT   16482.23   57354.85
# 75     11336377  1642155000032303    SB - RESIDENT   24471.10  438765.20
# 76      9550433  1689155000020433    SB - RESIDENT    2954.19   41177.98
# 77      8325616  1650155000059911    SB - RESIDENT   26393.52  441904.17
#
#         TOTCR  CTDR  CTCR       cAVGBAL    cTOTDR    cTOTCR     cCTDR  \
# ...

# %%
table = pd.pivot_table(features, index=['V_ACCT_NO'], values ='cAVGBAL', columns = ['V_PROD_DESC'])
table
# Out:
# V_PROD_DESC       FREEDOM SAVINGS  KVB JAN DHAN YOJANA (KVBJDY)  \
# V_ACCT_NO
# 1111155000026202              NaN                           NaN
# 1115155000070066              NaN                           NaN
# 1121155000157699              NaN                           NaN
# 1122166000015610              NaN                           NaN
# 1138155000084063              NaN                           NaN
# ...                           ...                           ...
# 1830155000014097              NaN                           NaN
# 2112155000023491              NaN                           NaN
# 2114155000009667              NaN                           NaN
# 4807177000000579              NaN                           NaN
# 4826166000003814              NaN                           NaN
#
# V_PROD_DESC       SB - KVB SAKTHI  SB - RAINBOW SB  SB - RESIDENT  \
# V_ACCT_NO
# 1111155000026202              NaN              NaN   1.046539e-14
# ...

# %%
d[["V_CUST_CODE", "V_PROD_DESC"]]
# Out:
#     V_CUST_CODE      V_PROD_DESC
# 0       9463999    SB - RESIDENT
# 1      10448555  FREEDOM SAVINGS
# 3        250651    SB - RESIDENT
# 4      15771490    SB - RESIDENT
# 5       7495557    SB - RESIDENT
# ..          ...              ...
# 73      9182599    SB - RESIDENT
# 74     16032572    SB - RESIDENT
# 75     11336377    SB - RESIDENT
# 76      9550433    SB - RESIDENT
# 77      8325616    SB - RESIDENT
#
# [64 rows x 2 columns]

# %%
spatial.distance.cosine(c,a)

# %%
yy = (z-np.median(z))/(np.percentile(z, 75)-np.percentile(z, 25))
yy
y = (x-np.median(x))/(np.percentile(x, 75)-np.percentile(x, 25))
y
# Out:
# 0     0.060834
# 1     0.133043
# 3    -0.297505
# 4     2.067829
# 5    -0.298845
#         ...
# 73   -0.307607
# 74    0.082807
# 75    2.756826
# 76   -0.030607
# 77    2.778833
# Name: TOTDR, Length: 64, dtype: float64

# %%
pd.DataFrame(yy).describe()
pd.DataFrame(y).describe()
# Out:
# 0    -0.274400
# 1    -0.120812
# 3     0.145957
# 4     7.745844
# 5    -0.375064
#         ...
# 73   -0.227248
# 74    0.306635
# 75    0.661699
# 76   -0.294616
# 77    0.747140
# Name: AVGBAL, Length: 64, dtype: float64

# %%
import numpy as np
def softmax(x):
    """Compute softmax values for each sets of scores in x."""
    e_x = np.exp(x - np.max(x))
    return e_x / e_x.sum()

# %%
softmax(y)
# Out:
# 1.0000000000000002

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled = scaler.fit_transform(y)
scaler.transform(y)

# %%
import numpy as np
y = x-np.median(x)/(np.percentile(x, 75)-np.percentile(x, 25))
y
# Out:
# 0       3408.604086
# 1       6864.324086
# 3      12866.574086
# 4     183862.764086
# 5       1143.684086
#           ...
# 73      4469.524086
# 74     16481.804086
# 75     24470.674086
# 76      2953.764086
# 77     26393.094086
# Name: AVGBAL, Length: 64, dtype: float64
